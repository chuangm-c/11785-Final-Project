# %%
import matplotlib.pyplot as plt

# Plot training loss and validation loss over epochs

ab3 = [5.5539,5.2241,4.7607,4.1402,3.6643,3.4238,2.8818,1.7044]
ab1 = [5.5505,5.5178,5.2567,4.8399,4.693,3.7524,2.597,2.0001]
ab2 = [5.5977,5.5441,5.4579,5.2023,4.7782,4.2065,3.7605,3.5591]

model2 = [5.6076,5.5697,5.5331,5.4913,5.2842,4.805,4.2964,3.2155]
model1 = [5.5621,5.5241,5.5012,5.4765,5.3217,5.1203,4.3278,3.7623]
model3 = [5.5409,5.5176,5.4928,5.4721,5.0982,4.6542,4.0928,3.0912]
model_base = [5.5539,5.5113,5.4612,5.2241,4.7607,4.1402,3.6643]

plt.plot(model_base, label='Meta N-20')
plt.plot(ab1, label='Ablation 1')
plt.plot(ab2, label='Ablation 2')
plt.plot(ab3, label='Ablation 3')

plt.plot(model1, label='Model 1')
plt.plot(model2, label='Model 2')
plt.plot(model3, label='Model 3')

plt.title('Training Loss across Models')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()


plt.tight_layout()
plt.show()

# %%
ab3 = [100 - x for x in [72.00,69.49,61.59]]
ab1 = [100 - x for x in [68.07,71.68,71.18,68.84,65.02]]
ab2 = [100 - x for x in [70.811,72.023,69.046,66.728]]

model2 = [100 - x for x in [70.84,72.23,69.89,69.34]]

model1 = [100 - x for x in [73.43,73.23,71.36]]

model3 = [100 - x for x in [72.2,71.9,70.1,69.04]]

model_base = [28,30]

plt.plot(model_base, label='Meta N-20')
plt.plot(ab1, label='Ablation 1')
plt.plot(ab2, label='Ablation 2')
plt.plot(ab3, label='Ablation 3')

plt.plot(model1, label='Model 1')
plt.plot(model2, label='Model 2')
plt.plot(model3, label='Model 3')

plt.title('Accuracy Vocab across Models (%)')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

# Set x-axis ticks to be integers
plt.xticks(range(max(len(ab1), len(ab2), len(ab3), len(model1), len(model2), len(model3), len(model_base))))


plt.tight_layout()
plt.show()
