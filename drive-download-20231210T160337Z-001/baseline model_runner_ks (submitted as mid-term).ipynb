# %% [markdown]
# ## Replicating Meta AI model

# %% [markdown]
# Meta AI: https://github.com/facebookresearch/brainmagick/tree/main

# %% [markdown]
# Table of contents:
# 1. Requirements
# 2. Data and studies
# 3. Preprocessing and cache
# 4. Training
# 5. Evaluations
# 6. Tests
# 7. Visualization of metrics

# %% [markdown]
# ### Requirements

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/Final_project/Baseline_model/brainmagick
# Out:
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick

# %%
ls
# Out:
# bm/                 logo.png                             notebook_templates/
# bm.egg-info/        Makefile                             outputs/
# brainmagick.png     MANIFEST.in                          pyproject.toml
# cache/              Miniconda3-latest-Linux-x86_64.sh    README.md
# CHANGELOG.md        Miniconda3-latest-Linux-x86_64.sh.1  requirements.txt
# CODE_OF_CONDUCT.md  Miniconda3-latest-Linux-x86_64.sh.2  scripts/
# CONTRIBUTING.md     Miniconda3-latest-Linux-x86_64.sh.3  setup.cfg
# data/               Miniconda3-latest-Linux-x86_64.sh.4  setup.py
# doc/                Miniconda3-latest-Linux-x86_64.sh.5
# LICENSE             mypy.ini

# %%
# !wget https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# !chmod +x Miniconda3-latest-Linux-x86_64.sh
# !bash ./Miniconda3-latest-Linux-x86_64.sh -b -f -p /usr/local

# %%
import sys
sys.path.append('/usr/local/lib/python3.8/site-packages')

# %%
# originally Meta AI had this line but it didn't work, so I replaced it with explicit package versions
# !conda install pytorch torchaudio cudatoolkit=11.3 -c pytorch -y

# %%
# !conda create -n bm ipython python=3.8 -y
# !conda activate bm
# !conda install pytorch=1.11.0 torchvision=0.12.0 torchaudio=0.11.0 cudatoolkit=11.3 -c pytorch
# !pip install -U -r requirements.txt
# !pip install -e .
# !python -m spacy download en_core_web_md

# %% [markdown]
# ### Data and studies

# %% [markdown]
# * `broderick2019`: EEG
# * `brennan2019`: EEG
#   * Version 1 (2019): used in Meta AI study, available at: `./data/brennan2019/`
#   * Version 2 (2023): updated version: https://deepblue.lib.umich.edu/data/concern/data_sets/bn999738r?locale=en
# * `audio_mous`: MEG
# * `gwilliams2022`: MEG, available at: `./data/gwilliams2022/` -- it's a default dataset used in `dora run ...`. If we want to use a different dataset, we need to overwrite the default version.

# %% [markdown]
# ### Preprocessing and cache

# %% [markdown]
# Key code:
# * `!dora run download_only=true` - downloads and preprocesses the default dataset (gwilliams2022).
# * `!dora run download_only=true 'dset.selections=[brennan2019]'` - downloads and preprocesses a selected dataset.

# %%
#!dora run download_only=true

# %%
# !dora run download_only=true 'dset.selections=[brennan2019]'
# Out:
# Hostname 2e465021a4a5 not defined in /conf/study_paths/study_paths.yaml. Using default paths.
# a
# /usr/local/lib/python3.11/site-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
# See https://hydra.cc/docs/1.2/upgrades/1.1_to_1.2/changes_to_job_working_dir/ for more information.
#   ret = run_job(
# [2023-11-14 09:01:34,474][bm._env][WARNING] - Hostname 2e465021a4a5 not defined in /conf/study_paths/study_paths.yaml. Using default paths.
# [2023-11-14 09:01:34,984][bm.train][INFO] - For logs, checkpoints and samples, check /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/outputs/xps/fa7ea8f3.
# [2023-11-14 09:01:34,985][bm.train][INFO] - Caching intermediate data under /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/cache.
# [11-14 09:01:34][dora.distrib][INFO] - world_size is 1, skipping init.
# [11-14 09:01:38][bm.dataset][WARNING] - Requested 1000 recordings but only found 33
# [11-14 09:02:00][bm.dataset][INFO] - Loading Subjects | 6/33 | 6.72 it/sec
# [11-14 09:02:01][bm.dataset][INFO] - Loading Subjects | 12/33 | 8.00 it/sec
# [11-14 09:02:02][bm.dataset][INFO] - Loading Subjects | 18/33 | 8.93 it/sec
# [11-14 09:02:02][bm.dataset][INFO] - Loading Subjects | 24/33 | 9.46 it/sec
# [11-14 09:02:03][bm.dataset][INFO] - Loading Subjects | 30/33 | 9.30 it/sec
# [11-14 09:02:03][bm.dataset][INFO] - # Examples (train | valid | test): 26283 | 6154 | 6265

# %% [markdown]
# ### Training

# %% [markdown]
# Key code:
# * `!dora run dset.n_recordings=1` - runs a training on the default dataset (gwilliams2022) using just 1 recording.
# * `!dora run 'dset.selections=[brennan2019]'` - runs a training on a selected dataset using all recordings. --> run; all subjects (get stuck on the normalization part for 6 hours).

# %%
# !dora run 'dset.selections=[brennan2019]' dset.n_recordings=10
# Out:
# Hostname 2e465021a4a5 not defined in /conf/study_paths/study_paths.yaml. Using default paths.
# a
# /usr/local/lib/python3.11/site-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
# See https://hydra.cc/docs/1.2/upgrades/1.1_to_1.2/changes_to_job_working_dir/ for more information.
#   ret = run_job(
# [2023-11-14 11:28:57,285][bm._env][WARNING] - Hostname 2e465021a4a5 not defined in /conf/study_paths/study_paths.yaml. Using default paths.
# [2023-11-14 11:28:57,320][bm.train][INFO] - For logs, checkpoints and samples, check /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/outputs/xps/54af1a5f.
# [2023-11-14 11:28:57,320][bm.train][INFO] - Caching intermediate data under /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/cache.
# [11-14 11:28:57][dora.distrib][INFO] - world_size is 1, skipping init.
# [11-14 11:28:59][bm.dataset][INFO] - Loading Subjects | 2/10 | 4.78 it/sec
# [11-14 11:28:59][bm.dataset][INFO] - Loading Subjects | 4/10 | 6.21 it/sec
# [11-14 11:28:59][bm.dataset][INFO] - Loading Subjects | 6/10 | 7.13 it/sec
# [11-14 11:29:00][bm.dataset][INFO] - Loading Subjects | 8/10 | 7.81 it/sec
# [11-14 11:29:00][bm.dataset][INFO] - # Examples (train | valid | test): 7980 | 1860 | 1898
# [11-14 11:29:00][bm.train][INFO] - Model hash: 3ee6c09951f37864a39f9610327de0c993e8e3f4
# /usr/local/lib/python3.11/site-packages/flashy/loggers/tensorboard.py:47: UserWarning: tensorboard package was not found: use pip install tensorboard
#   warnings.warn("tensorboard package was not found: use pip install tensorboard")
# [11-14 11:29:01][bm.solver][INFO] - Scaler cache file /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/cache/scaler/390fcc691b009c07/bf21a9e8fbc5a384.pkl
# [11-14 11:30:31][flashy.solver][INFO] - Train | Epoch 1 | 6/32 | 12.8 sec/it | loss 5.6121
# [11-14 11:31:37][flashy.solver][INFO] - Train | Epoch 1 | 12/32 | 12.0 sec/it | loss 5.5864
# [11-14 11:32:43][flashy.solver][INFO] - Train | Epoch 1 | 18/32 | 11.7 sec/it | loss 5.5767
# [11-14 11:33:47][flashy.solver][INFO] - Train | Epoch 1 | 24/32 | 11.4 sec/it | loss 5.5687
# [11-14 11:34:50][flashy.solver][INFO] - Train | Epoch 1 | 30/32 | 11.3 sec/it | loss 5.5636
# [11-14 11:34:50][flashy.solver][INFO] - Train Summary | Epoch 1 | loss=5.5076 | duration=349.2802
# [11-14 11:35:14][flashy.solver][INFO] - Valid | Epoch 1 | 1/8 | 12.0 sec/it | loss 5.6749
# [11-14 11:35:37][flashy.solver][INFO] - Valid | Epoch 1 | 2/8 | 15.6 sec/it | loss 5.6409
# [11-14 11:35:37][flashy.solver][INFO] - Valid | Epoch 1 | 3/8 | 11.8 sec/it | loss 5.6235
# [11-14 11:36:00][flashy.solver][INFO] - Valid | Epoch 1 | 4/8 | 13.9 sec/it | loss 5.6203
# [11-14 11:36:00][flashy.solver][INFO] - Valid | Epoch 1 | 5/8 | 11.6 sec/it | loss 5.6072
# [11-14 11:36:21][flashy.solver][INFO] - Valid | Epoch 1 | 6/8 | 12.9 sec/it | loss 5.6018
# [11-14 11:36:21][flashy.solver][INFO] - Valid | Epoch 1 | 7/8 | 11.3 sec/it | loss 5.4703
# [11-14 11:36:21][bm.solver][INFO] - New best valid loss 5.4703
# [11-14 11:36:21][flashy.solver][INFO] - Valid Summary | Epoch 1 | loss=5.4703 | duration=90.7531
# [11-14 11:36:46][bm.wer][INFO] - WER | 1/8 | 12.6 sec/it
# [11-14 11:37:08][bm.wer][INFO] - WER | 2/8 | 15.7 sec/it
# [11-14 11:37:09][bm.wer][INFO] - WER | 3/8 | 12.0 sec/it
# [11-14 11:37:30][bm.wer][INFO] - WER | 4/8 | 13.8 sec/it
# [11-14 11:37:31][bm.wer][INFO] - WER | 5/8 | 11.7 sec/it
# [11-14 11:37:51][bm.wer][INFO] - WER | 6/8 | 12.9 sec/it
# [11-14 11:37:51][bm.wer][INFO] - WER | 7/8 | 11.3 sec/it
# [11-14 11:37:57][bm.wer][INFO] - wer 1898 negatives selected
# [11-14 11:38:01][bm.wer][INFO] - WER Rank | 379/1898 | 118.13 it/sec
# [11-14 11:38:04][bm.wer][INFO] - WER Rank | 758/1898 | 122.35 it/sec
# [11-14 11:38:07][bm.wer][INFO] - WER Rank | 1137/1898 | 123.65 it/sec
# [11-14 11:38:10][bm.wer][INFO] - WER Rank | 1516/1898 | 124.20 it/sec
# [11-14 11:38:13][bm.wer][INFO] - WER Rank | 1895/1898 | 124.68 it/sec
# [11-14 11:38:13][flashy.solver][INFO] - Test Summary | Epoch 1 | wer=97.998% | wer_vocab=70.864% | duration=112.2134
# [11-14 11:38:13][bm.solver][INFO] - Scale Reject | Ratio 0.000%
# [11-14 11:39:41][flashy.solver][INFO] - Train | Epoch 2 | 6/32 | 12.4 sec/it | loss 5.5121
# [11-14 11:40:46][flashy.solver][INFO] - Train | Epoch 2 | 12/32 | 11.7 sec/it | loss 5.5078
# [11-14 11:41:52][flashy.solver][INFO] - Train | Epoch 2 | 18/32 | 11.5 sec/it | loss 5.5093
# [11-14 11:42:56][flashy.solver][INFO] - Train | Epoch 2 | 24/32 | 11.3 sec/it | loss 5.5095
# [11-14 11:43:59][flashy.solver][INFO] - Train | Epoch 2 | 30/32 | 11.1 sec/it | loss 5.5063
# [11-14 11:43:59][flashy.solver][INFO] - Train Summary | Epoch 2 | loss=5.4549 | duration=345.7042
# [11-14 11:44:24][flashy.solver][INFO] - Valid | Epoch 2 | 1/8 | 12.2 sec/it | loss 5.5587
# [11-14 11:44:46][flashy.solver][INFO] - Valid | Epoch 2 | 2/8 | 15.5 sec/it | loss 5.5765
# [11-14 11:44:46][flashy.solver][INFO] - Valid | Epoch 2 | 3/8 | 11.7 sec/it | loss 5.5900
# [11-14 11:45:08][flashy.solver][INFO] - Valid | Epoch 2 | 4/8 | 13.7 sec/it | loss 5.5874
# [11-14 11:45:09][flashy.solver][INFO] - Valid | Epoch 2 | 5/8 | 11.6 sec/it | loss 5.5871
# [11-14 11:45:28][flashy.solver][INFO] - Valid | Epoch 2 | 6/8 | 12.7 sec/it | loss 5.5867
# [11-14 11:45:28][flashy.solver][INFO] - Valid | Epoch 2 | 7/8 | 11.1 sec/it | loss 5.4179
# [11-14 11:45:28][bm.solver][INFO] - New best valid loss 5.4179
# [11-14 11:45:28][flashy.solver][INFO] - Valid Summary | Epoch 2 | loss=5.4179 | duration=89.0749
# [11-14 11:45:53][bm.wer][INFO] - WER | 1/8 | 12.5 sec/it
# [11-14 11:46:14][bm.wer][INFO] - WER | 2/8 | 15.2 sec/it
# [11-14 11:46:15][bm.wer][INFO] - WER | 3/8 | 11.7 sec/it
# [11-14 11:46:36][bm.wer][INFO] - WER | 4/8 | 13.5 sec/it
# [11-14 11:46:37][bm.wer][INFO] - WER | 5/8 | 11.4 sec/it
# [11-14 11:46:57][bm.wer][INFO] - WER | 6/8 | 12.7 sec/it
# [11-14 11:46:58][bm.wer][INFO] - WER | 7/8 | 11.2 sec/it
# [11-14 11:47:03][bm.wer][INFO] - wer 1898 negatives selected
# [11-14 11:47:06][bm.wer][INFO] - WER Rank | 379/1898 | 127.00 it/sec
# [11-14 11:47:09][bm.wer][INFO] - WER Rank | 758/1898 | 127.36 it/sec
# [11-14 11:47:12][bm.wer][INFO] - WER Rank | 1137/1898 | 127.44 it/sec
# [11-14 11:47:15][bm.wer][INFO] - WER Rank | 1516/1898 | 127.44 it/sec
# [11-14 11:47:18][bm.wer][INFO] - WER Rank | 1895/1898 | 127.36 it/sec
# [11-14 11:47:19][flashy.solver][INFO] - Test Summary | Epoch 2 | wer=98.103% | wer_vocab=71.812% | duration=110.5879
# [11-14 11:47:19][bm.solver][INFO] - Scale Reject | Ratio 0.000%
# [11-14 11:48:50][flashy.solver][INFO] - Train | Epoch 3 | 6/32 | 12.9 sec/it | loss 5.4893
# [11-14 11:49:54][flashy.solver][INFO] - Train | Epoch 3 | 12/32 | 11.9 sec/it | loss 5.4760
# [11-14 11:50:59][flashy.solver][INFO] - Train | Epoch 3 | 18/32 | 11.5 sec/it | loss 5.4718
# [11-14 11:52:04][flashy.solver][INFO] - Train | Epoch 3 | 24/32 | 11.4 sec/it | loss 5.4615
# [11-14 11:53:07][flashy.solver][INFO] - Train | Epoch 3 | 30/32 | 11.2 sec/it | loss 5.4582
# [11-14 11:53:08][flashy.solver][INFO] - Train Summary | Epoch 3 | loss=5.3987 | duration=348.1909
# [11-14 11:53:32][flashy.solver][INFO] - Valid | Epoch 3 | 1/8 | 12.0 sec/it | loss 5.6886
# [11-14 11:53:55][flashy.solver][INFO] - Valid | Epoch 3 | 2/8 | 15.7 sec/it | loss 5.6687
# [11-14 11:53:56][flashy.solver][INFO] - Valid | Epoch 3 | 3/8 | 12.1 sec/it | loss 5.6610
# [11-14 11:54:17][flashy.solver][INFO] - Valid | Epoch 3 | 4/8 | 13.9 sec/it | loss 5.6883
# [11-14 11:54:18][flashy.solver][INFO] - Valid | Epoch 3 | 5/8 | 11.8 sec/it | loss 5.6935
# [11-14 11:54:38][flashy.solver][INFO] - Valid | Epoch 3 | 6/8 | 12.9 sec/it | loss 5.6855
# [11-14 11:54:38][flashy.solver][INFO] - Valid | Epoch 3 | 7/8 | 11.3 sec/it | loss 5.5027
# [11-14 11:54:38][flashy.solver][INFO] - Valid Summary | Epoch 3 | loss=5.5027 | duration=90.6104
# [11-14 11:54:38][bm.solver][INFO] - Scale Reject | Ratio 0.000%
# [11-14 11:56:08][flashy.solver][INFO] - Train | Epoch 4 | 6/32 | 12.8 sec/it | loss 5.4093
# [11-14 11:57:15][flashy.solver][INFO] - Train | Epoch 4 | 12/32 | 12.1 sec/it | loss 5.4098
# [11-14 11:58:21][flashy.solver][INFO] - Train | Epoch 4 | 18/32 | 11.7 sec/it | loss 5.3962
# [11-14 11:59:26][flashy.solver][INFO] - Train | Epoch 4 | 24/32 | 11.5 sec/it | loss 5.3832
# [11-14 12:00:31][flashy.solver][INFO] - Train | Epoch 4 | 30/32 | 11.4 sec/it | loss 5.3652
# [11-14 12:00:31][flashy.solver][INFO] - Train Summary | Epoch 4 | loss=5.3033 | duration=352.3337
# [11-14 12:00:54][flashy.solver][INFO] - Valid | Epoch 4 | 1/8 | 11.5 sec/it | loss 5.8129
# [11-14 12:01:16][flashy.solver][INFO] - Valid | Epoch 4 | 2/8 | 14.9 sec/it | loss 5.7942
# [11-14 12:01:16][flashy.solver][INFO] - Valid | Epoch 4 | 3/8 | 11.3 sec/it | loss 5.7957
# [11-14 12:01:37][flashy.solver][INFO] - Valid | Epoch 4 | 4/8 | 13.3 sec/it | loss 5.7857
# [11-14 12:01:39][flashy.solver][INFO] - Valid | Epoch 4 | 5/8 | 11.3 sec/it | loss 5.7785
# [11-14 12:01:59][flashy.solver][INFO] - Valid | Epoch 4 | 6/8 | 12.5 sec/it | loss 5.7845
# [11-14 12:01:59][flashy.solver][INFO] - Valid | Epoch 4 | 7/8 | 11.0 sec/it | loss 5.5838
# [11-14 12:01:59][flashy.solver][INFO] - Valid Summary | Epoch 4 | loss=5.5838 | duration=87.8907
# [11-14 12:01:59][bm.solver][INFO] - Scale Reject | Ratio 0.000%
# [11-14 12:03:28][flashy.solver][INFO] - Train | Epoch 5 | 6/32 | 12.7 sec/it | loss 5.2527
# [11-14 12:04:33][flashy.solver][INFO] - Train | Epoch 5 | 12/32 | 11.9 sec/it | loss 5.2322
# [11-14 12:05:38][flashy.solver][INFO] - Train | Epoch 5 | 18/32 | 11.5 sec/it | loss 5.2143
# [11-14 12:06:46][flashy.solver][INFO] - Train | Epoch 5 | 24/32 | 11.5 sec/it | loss 5.1805
# [11-14 12:07:50][flashy.solver][INFO] - Train | Epoch 5 | 30/32 | 11.3 sec/it | loss 5.1658
# [11-14 12:07:51][flashy.solver][INFO] - Train Summary | Epoch 5 | loss=5.1026 | duration=351.3258
# [11-14 12:08:14][flashy.solver][INFO] - Valid | Epoch 5 | 1/8 | 11.5 sec/it | loss 5.8649
# [11-14 12:08:36][flashy.solver][INFO] - Valid | Epoch 5 | 2/8 | 15.2 sec/it | loss 5.8464
# [11-14 12:08:37][flashy.solver][INFO] - Valid | Epoch 5 | 3/8 | 11.5 sec/it | loss 5.8698
# [11-14 12:08:59][flashy.solver][INFO] - Valid | Epoch 5 | 4/8 | 13.6 sec/it | loss 5.8523
# [11-14 12:09:00][flashy.solver][INFO] - Valid | Epoch 5 | 5/8 | 11.5 sec/it | loss 5.8438
# [11-14 12:09:20][flashy.solver][INFO] - Valid | Epoch 5 | 6/8 | 12.8 sec/it | loss 5.8306
# [11-14 12:09:20][flashy.solver][INFO] - Valid | Epoch 5 | 7/8 | 11.2 sec/it | loss 5.6360
# [11-14 12:09:20][flashy.solver][INFO] - Valid Summary | Epoch 5 | loss=5.6360 | duration=89.6178
# [11-14 12:09:20][bm.solver][INFO] - Scale Reject | Ratio 0.000%
# [11-14 12:10:49][flashy.solver][INFO] - Train | Epoch 6 | 6/32 | 12.7 sec/it | loss 5.1715
# [11-14 12:11:54][flashy.solver][INFO] - Train | Epoch 6 | 12/32 | 11.8 sec/it | loss 5.1691
# [11-14 12:12:59][flashy.solver][INFO] - Train | Epoch 6 | 18/32 | 11.5 sec/it | loss 5.1469
# [11-14 12:14:04][flashy.solver][INFO] - Train | Epoch 6 | 24/32 | 11.3 sec/it | loss 5.1290
# [11-14 12:15:09][flashy.solver][INFO] - Train | Epoch 6 | 30/32 | 11.2 sec/it | loss 5.1060
# [11-14 12:15:09][flashy.solver][INFO] - Train Summary | Epoch 6 | loss=5.0510 | duration=348.3421
# [11-14 12:15:32][flashy.solver][INFO] - Valid | Epoch 6 | 1/8 | 11.6 sec/it | loss 5.8933
# [11-14 12:15:53][flashy.solver][INFO] - Valid | Epoch 6 | 2/8 | 14.7 sec/it | loss 5.8442
# [11-14 12:15:54][flashy.solver][INFO] - Valid | Epoch 6 | 3/8 | 11.3 sec/it | loss 5.8371
# [11-14 12:16:14][flashy.solver][INFO] - Valid | Epoch 6 | 4/8 | 13.0 sec/it | loss 5.8746
# [11-14 12:16:17][flashy.solver][INFO] - Valid | Epoch 6 | 5/8 | 11.3 sec/it | loss 5.8493
# [11-14 12:16:35][flashy.solver][INFO] - Valid | Epoch 6 | 6/8 | 12.3 sec/it | loss 5.8427
# [11-14 12:16:35][flashy.solver][INFO] - Valid | Epoch 6 | 7/8 | 10.8 sec/it | loss 5.6928
# [11-14 12:16:35][flashy.solver][INFO] - Valid Summary | Epoch 6 | loss=5.6928 | duration=86.4524
# [11-14 12:16:35][bm.solver][INFO] - Scale Reject | Ratio 0.000%
# [11-14 12:18:02][flashy.solver][INFO] - Train | Epoch 7 | 6/32 | 12.3 sec/it | loss 4.8338
# [11-14 12:19:08][flashy.solver][INFO] - Train | Epoch 7 | 12/32 | 11.7 sec/it | loss 4.7853
# [11-14 12:20:12][flashy.solver][INFO] - Train | Epoch 7 | 18/32 | 11.4 sec/it | loss 4.7601
# [11-14 12:21:17][flashy.solver][INFO] - Train | Epoch 7 | 24/32 | 11.2 sec/it | loss 4.7259
# [11-14 12:22:19][flashy.solver][INFO] - Train | Epoch 7 | 30/32 | 11.1 sec/it | loss 4.6950
# [11-14 12:22:20][flashy.solver][INFO] - Train Summary | Epoch 7 | loss=4.6416 | duration=343.7491
# [11-14 12:22:42][flashy.solver][INFO] - Valid | Epoch 7 | 1/8 | 11.4 sec/it | loss 5.9917
# [11-14 12:23:04][flashy.solver][INFO] - Valid | Epoch 7 | 2/8 | 14.7 sec/it | loss 6.0071
# [11-14 12:23:04][flashy.solver][INFO] - Valid | Epoch 7 | 3/8 | 11.1 sec/it | loss 6.0398
# [11-14 12:23:27][flashy.solver][INFO] - Valid | Epoch 7 | 4/8 | 13.4 sec/it | loss 6.0324
# [11-14 12:23:27][flashy.solver][INFO] - Valid | Epoch 7 | 5/8 | 11.2 sec/it | loss 6.0148
# [11-14 12:23:47][flashy.solver][INFO] - Valid | Epoch 7 | 6/8 | 12.4 sec/it | loss 6.0312
# [11-14 12:23:47][flashy.solver][INFO] - Valid | Epoch 7 | 7/8 | 10.9 sec/it | loss 5.8516
# [11-14 12:23:47][flashy.solver][INFO] - Valid Summary | Epoch 7 | loss=5.8516 | duration=87.2114
# [11-14 12:23:47][bm.solver][WARNING] - Model valid_loss did not improve for 5 epochs. Stopping the training.
# [11-14 12:23:47][bm.solver][INFO] - Scale Reject | Ratio 0.000%

# %%
# !dora run 'dset.selections=[brennan2019]' dset.n_recordings=20
# Out:
# Hostname 48d7219ef932 not defined in /conf/study_paths/study_paths.yaml. Using default paths.
# a
# /usr/local/lib/python3.11/site-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
# See https://hydra.cc/docs/1.2/upgrades/1.1_to_1.2/changes_to_job_working_dir/ for more information.
#   ret = run_job(
# [2023-11-14 19:10:26,257][bm._env][WARNING] - Hostname 48d7219ef932 not defined in /conf/study_paths/study_paths.yaml. Using default paths.
# [2023-11-14 19:10:26,258][bm.train][INFO] - For logs, checkpoints and samples, check /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/outputs/xps/1f75090d.
# [2023-11-14 19:10:26,259][bm.train][INFO] - Caching intermediate data under /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/cache.
# [11-14 19:10:26][dora.distrib][INFO] - world_size is 1, skipping init.
# [11-14 19:10:48][bm.dataset][INFO] - Loading Subjects | 4/20 | 4.89 it/sec
# [11-14 19:10:49][bm.dataset][INFO] - Loading Subjects | 8/20 | 6.56 it/sec
# [11-14 19:10:49][bm.dataset][INFO] - Loading Subjects | 12/20 | 7.56 it/sec
# [11-14 19:10:49][bm.dataset][INFO] - Loading Subjects | 16/20 | 8.22 it/sec
# [11-14 19:10:50][bm.dataset][INFO] - # Examples (train | valid | test): 15951 | 3724 | 3796
# [11-14 19:10:54][bm.train][INFO] - Model hash: 785fadb9762536b72e9ac880af8382ac5efdfefe
# /usr/local/lib/python3.11/site-packages/flashy/loggers/tensorboard.py:47: UserWarning: tensorboard package was not found: use pip install tensorboard
#   warnings.warn("tensorboard package was not found: use pip install tensorboard")
# [11-14 19:10:55][bm.solver][INFO] - Fitting scaler. Dataset size=15951 samples.
# [11-14 19:12:56][bm.norm][INFO] - Fitting scalers | 4/20 | 24.3 sec/it
# [11-14 19:14:23][bm.norm][INFO] - Fitting scalers | 8/20 | 23.2 sec/it
# [11-14 19:15:42][bm.norm][INFO] - Fitting scalers | 12/20 | 22.1 sec/it
# [11-14 19:17:00][bm.norm][INFO] - Fitting scalers | 16/20 | 21.5 sec/it
# [11-14 19:18:26][bm.norm][INFO] - features collected for norm: torch.Size([1848320, 1024])
# [11-14 19:19:39][bm.solver][INFO] - Scaler cache file /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/cache/scaler/37483796bce6ae2a/bf21a9e8fbc5a384.pkl
# [11-14 19:22:19][flashy.solver][INFO] - Train | Epoch 1 | 12/63 | 12.3 sec/it | loss 5.6030
# [11-14 19:24:32][flashy.solver][INFO] - Train | Epoch 1 | 24/63 | 11.7 sec/it | loss 5.5891
# [11-14 19:26:48][flashy.solver][INFO] - Train | Epoch 1 | 36/63 | 11.6 sec/it | loss 5.5834
# [11-14 19:29:01][flashy.solver][INFO] - Train | Epoch 1 | 48/63 | 11.5 sec/it | loss 5.5788
# [11-14 19:31:17][flashy.solver][INFO] - Train | Epoch 1 | 60/63 | 11.4 sec/it | loss 5.5730
# [11-14 19:31:23][flashy.solver][INFO] - Train Summary | Epoch 1 | loss=5.5539 | duration=704.0414
# [11-14 19:32:57][flashy.solver][INFO] - Valid | Epoch 1 | 3/15 | 23.4 sec/it | loss 5.5557
# [11-14 19:33:41][flashy.solver][INFO] - Valid | Epoch 1 | 6/15 | 19.7 sec/it | loss 5.5562
# [11-14 19:34:08][flashy.solver][INFO] - Valid | Epoch 1 | 9/15 | 16.4 sec/it | loss 5.5589
# [11-14 19:34:51][flashy.solver][INFO] - Valid | Epoch 1 | 12/15 | 16.0 sec/it | loss 5.5581
# [11-14 19:35:03][bm.solver][INFO] - New best valid loss 5.5165
# [11-14 19:35:03][flashy.solver][INFO] - Valid Summary | Epoch 1 | loss=5.5165 | duration=219.5224
# Downloading (…)rocessor_config.json: 100% 212/212 [00:00<00:00, 967kB/s]
# Downloading (…)lve/main/config.json: 100% 1.77k/1.77k [00:00<00:00, 11.0MB/s]
# Downloading pytorch_model.bin: 100% 1.27G/1.27G [00:03<00:00, 342MB/s]
# [11-14 19:36:46][bm.wer][INFO] - WER | 3/15 | 25.7 sec/it
# [11-14 19:37:31][bm.wer][INFO] - WER | 6/15 | 21.0 sec/it
# [11-14 19:37:58][bm.wer][INFO] - WER | 9/15 | 17.5 sec/it
# [11-14 19:38:41][bm.wer][INFO] - WER | 12/15 | 16.7 sec/it
# [11-14 19:39:08][bm.wer][INFO] - wer 3796 negatives selected
# [11-14 19:39:21][bm.wer][INFO] - WER Rank | 759/3796 | 70.20 it/sec
# [11-14 19:39:31][bm.wer][INFO] - WER Rank | 1518/3796 | 70.84 it/sec
# [11-14 19:39:42][bm.wer][INFO] - WER Rank | 2277/3796 | 70.96 it/sec
# [11-14 19:39:53][bm.wer][INFO] - WER Rank | 3036/3796 | 71.03 it/sec
# [11-14 19:40:03][bm.wer][INFO] - WER Rank | 3795/3796 | 71.11 it/sec
# [11-14 19:40:04][flashy.solver][INFO] - Test Summary | Epoch 1 | wer=98.815% | wer_vocab=71.997% | duration=301.2489
# [11-14 19:40:04][bm.solver][INFO] - Scale Reject | Ratio 0.000%
# [11-14 19:42:45][flashy.solver][INFO] - Train | Epoch 2 | 12/63 | 12.3 sec/it | loss 5.5385
# [11-14 19:45:04][flashy.solver][INFO] - Train | Epoch 2 | 24/63 | 12.0 sec/it | loss 5.5342
# [11-14 19:47:19][flashy.solver][INFO] - Train | Epoch 2 | 36/63 | 11.7 sec/it | loss 5.5331
# [11-14 19:49:38][flashy.solver][INFO] - Train | Epoch 2 | 48/63 | 11.7 sec/it | loss 5.5324
# [11-14 19:51:53][flashy.solver][INFO] - Train | Epoch 2 | 60/63 | 11.6 sec/it | loss 5.5293
# [11-14 19:51:59][flashy.solver][INFO] - Train Summary | Epoch 2 | loss=5.5113 | duration=713.8674
# [11-14 19:52:47][flashy.solver][INFO] - Valid | Epoch 2 | 3/15 | 12.0 sec/it | loss 5.5626
# [11-14 19:53:32][flashy.solver][INFO] - Valid | Epoch 2 | 6/15 | 13.3 sec/it | loss 5.5662
# [11-14 19:53:57][flashy.solver][INFO] - Valid | Epoch 2 | 9/15 | 11.9 sec/it | loss 5.5616
# [11-14 19:54:41][flashy.solver][INFO] - Valid | Epoch 2 | 12/15 | 12.5 sec/it | loss 5.5638
# [11-14 19:54:52][flashy.solver][INFO] - Valid Summary | Epoch 2 | loss=5.5224 | duration=173.7549
# [11-14 19:54:52][bm.solver][INFO] - Scale Reject | Ratio 0.000%
# [11-14 19:57:35][flashy.solver][INFO] - Train | Epoch 3 | 12/63 | 12.4 sec/it | loss 5.5001
# [11-14 19:59:51][flashy.solver][INFO] - Train | Epoch 3 | 24/63 | 11.9 sec/it | loss 5.4974
# [11-14 20:02:11][flashy.solver][INFO] - Train | Epoch 3 | 36/63 | 11.8 sec/it | loss 5.4911
# [11-14 20:04:28][flashy.solver][INFO] - Train | Epoch 3 | 48/63 | 11.7 sec/it | loss 5.4916
# [11-14 20:06:46][flashy.solver][INFO] - Train | Epoch 3 | 60/63 | 11.7 sec/it | loss 5.4823
# [11-14 20:06:53][flashy.solver][INFO] - Train Summary | Epoch 3 | loss=5.4612 | duration=720.0911
# [11-14 20:07:43][flashy.solver][INFO] - Valid | Epoch 3 | 3/15 | 12.6 sec/it | loss 5.5560
# [11-14 20:08:29][flashy.solver][INFO] - Valid | Epoch 3 | 6/15 | 13.7 sec/it | loss 5.5568
# [11-14 20:08:53][flashy.solver][INFO] - Valid | Epoch 3 | 9/15 | 12.0 sec/it | loss 5.5556
# [11-14 20:09:39][flashy.solver][INFO] - Valid | Epoch 3 | 12/15 | 12.8 sec/it | loss 5.5572
# [11-14 20:09:51][flashy.solver][INFO] - Valid Summary | Epoch 3 | loss=5.5175 | duration=177.9207
# [11-14 20:09:51][bm.solver][INFO] - Scale Reject | Ratio 0.000%
# [11-14 20:12:32][flashy.solver][INFO] - Train | Epoch 4 | 12/63 | 12.4 sec/it | loss 5.3359
# [11-14 20:14:48][flashy.solver][INFO] - Train | Epoch 4 | 24/63 | 11.9 sec/it | loss 5.3267
# [11-14 20:17:03][flashy.solver][INFO] - Train | Epoch 4 | 36/63 | 11.7 sec/it | loss 5.3167
# [11-14 20:19:22][flashy.solver][INFO] - Train | Epoch 4 | 48/63 | 11.7 sec/it | loss 5.2816
# [11-14 20:21:38][flashy.solver][INFO] - Train | Epoch 4 | 60/63 | 11.6 sec/it | loss 5.2470
# [11-14 20:21:45][flashy.solver][INFO] - Train Summary | Epoch 4 | loss=5.2241 | duration=713.3263
# [11-14 20:22:32][flashy.solver][INFO] - Valid | Epoch 4 | 3/15 | 12.0 sec/it | loss 5.3588
# [11-14 20:23:20][flashy.solver][INFO] - Valid | Epoch 4 | 6/15 | 13.7 sec/it | loss 5.3767
# [11-14 20:23:44][flashy.solver][INFO] - Valid | Epoch 4 | 9/15 | 12.0 sec/it | loss 5.3770
# [11-14 20:24:31][flashy.solver][INFO] - Valid | Epoch 4 | 12/15 | 12.8 sec/it | loss 5.3664
# [11-14 20:24:43][bm.solver][INFO] - New best valid loss 5.3195
# [11-14 20:24:43][flashy.solver][INFO] - Valid Summary | Epoch 4 | loss=5.3195 | duration=178.5949
# [11-14 20:25:33][bm.wer][INFO] - WER | 3/15 | 12.5 sec/it
# [11-14 20:26:18][bm.wer][INFO] - WER | 6/15 | 13.6 sec/it
# [11-14 20:26:43][bm.wer][INFO] - WER | 9/15 | 12.0 sec/it
# [11-14 20:27:30][bm.wer][INFO] - WER | 12/15 | 12.8 sec/it
# [11-14 20:27:57][bm.wer][INFO] - wer 3796 negatives selected
# [11-14 20:28:09][bm.wer][INFO] - WER Rank | 759/3796 | 71.09 it/sec
# [11-14 20:28:19][bm.wer][INFO] - WER Rank | 1518/3796 | 71.16 it/sec
# [11-14 20:28:30][bm.wer][INFO] - WER Rank | 2277/3796 | 70.95 it/sec
# [11-14 20:28:41][bm.wer][INFO] - WER Rank | 3036/3796 | 71.01 it/sec
# [11-14 20:28:52][bm.wer][INFO] - WER Rank | 3795/3796 | 70.98 it/sec
# [11-14 20:28:53][flashy.solver][INFO] - Test Summary | Epoch 4 | wer=95.969% | wer_vocab=69.494% | duration=249.5078
# [11-14 20:28:53][bm.solver][INFO] - Scale Reject | Ratio 0.000%
# [11-14 20:31:37][flashy.solver][INFO] - Train | Epoch 5 | 12/63 | 12.6 sec/it | loss 4.9510
# [11-14 20:33:58][flashy.solver][INFO] - Train | Epoch 5 | 24/63 | 12.2 sec/it | loss 4.8962
# [11-14 20:36:19][flashy.solver][INFO] - Train | Epoch 5 | 36/63 | 12.0 sec/it | loss 4.8448
# [11-14 20:38:37][flashy.solver][INFO] - Train | Epoch 5 | 48/63 | 11.9 sec/it | loss 4.8147
# [11-14 20:40:57][flashy.solver][INFO] - Train | Epoch 5 | 60/63 | 11.9 sec/it | loss 4.7858
# [11-14 20:41:03][flashy.solver][INFO] - Train Summary | Epoch 5 | loss=4.7607 | duration=729.6058
# [11-14 20:41:51][flashy.solver][INFO] - Valid | Epoch 5 | 3/15 | 12.1 sec/it | loss 5.4482
# [11-14 20:42:39][flashy.solver][INFO] - Valid | Epoch 5 | 6/15 | 13.7 sec/it | loss 5.4491
# [11-14 20:43:02][flashy.solver][INFO] - Valid | Epoch 5 | 9/15 | 12.0 sec/it | loss 5.4359
# [11-14 20:43:48][flashy.solver][INFO] - Valid | Epoch 5 | 12/15 | 12.7 sec/it | loss 5.4214
# [11-14 20:44:00][flashy.solver][INFO] - Valid Summary | Epoch 5 | loss=5.3667 | duration=177.7044
# [11-14 20:44:00][bm.solver][INFO] - Scale Reject | Ratio 0.000%
# [11-14 20:46:43][flashy.solver][INFO] - Train | Epoch 6 | 12/63 | 12.5 sec/it | loss 4.3923
# [11-14 20:49:01][flashy.solver][INFO] - Train | Epoch 6 | 24/63 | 12.0 sec/it | loss 4.3121
# [11-14 20:51:20][flashy.solver][INFO] - Train | Epoch 6 | 36/63 | 11.9 sec/it | loss 4.2541
# [11-14 20:53:41][flashy.solver][INFO] - Train | Epoch 6 | 48/63 | 11.8 sec/it | loss 4.2144
# [11-14 20:55:58][flashy.solver][INFO] - Train | Epoch 6 | 60/63 | 11.8 sec/it | loss 4.1641
# [11-14 20:56:05][flashy.solver][INFO] - Train Summary | Epoch 6 | loss=4.1402 | duration=723.9366
# [11-14 20:56:52][flashy.solver][INFO] - Valid | Epoch 6 | 3/15 | 11.8 sec/it | loss 5.6222
# [11-14 20:57:41][flashy.solver][INFO] - Valid | Epoch 6 | 6/15 | 13.8 sec/it | loss 5.6619
# [11-14 20:58:05][flashy.solver][INFO] - Valid | Epoch 6 | 9/15 | 12.0 sec/it | loss 5.6782
# [11-14 20:58:53][flashy.solver][INFO] - Valid | Epoch 6 | 12/15 | 12.9 sec/it | loss 5.6818
# [11-14 20:59:06][flashy.solver][INFO] - Valid Summary | Epoch 6 | loss=5.6375 | duration=180.7875
# [11-14 20:59:06][bm.solver][INFO] - Scale Reject | Ratio 0.000%
# [11-14 21:01:47][flashy.solver][INFO] - Train | Epoch 7 | 12/63 | 12.4 sec/it | loss 3.7022
# [11-14 21:04:06][flashy.solver][INFO] - Train | Epoch 7 | 24/63 | 12.0 sec/it | loss 3.6815
# [11-14 21:06:24][flashy.solver][INFO] - Train | Epoch 7 | 36/63 | 11.8 sec/it | loss 3.6460
# [11-14 21:08:42][flashy.solver][INFO] - Train | Epoch 7 | 48/63 | 11.7 sec/it | loss 3.5824
# [11-14 21:11:00][flashy.solver][INFO] - Train | Epoch 7 | 60/63 | 11.7 sec/it | loss 3.6499
# [11-14 21:11:06][flashy.solver][INFO] - Train Summary | Epoch 7 | loss=3.6643 | duration=720.2842
# [11-14 21:11:55][flashy.solver][INFO] - Valid | Epoch 7 | 3/15 | 12.2 sec/it | loss 6.1448
# [11-14 21:12:41][flashy.solver][INFO] - Valid | Epoch 7 | 6/15 | 13.5 sec/it | loss 6.1895
# [11-14 21:13:05][flashy.solver][INFO] - Valid | Epoch 7 | 9/15 | 11.9 sec/it | loss 6.1471
# [11-14 21:13:53][flashy.solver][INFO] - Valid | Epoch 7 | 12/15 | 12.8 sec/it | loss 6.1550
# [11-14 21:14:05][flashy.solver][INFO] - Valid Summary | Epoch 7 | loss=6.0911 | duration=178.6000
# [11-14 21:14:05][bm.solver][INFO] - Scale Reject | Ratio 0.000%
# [11-14 21:16:47][flashy.solver][INFO] - Train | Epoch 8 | 12/63 | 12.4 sec/it | loss 4.5464
# [11-14 21:19:05][flashy.solver][INFO] - Train | Epoch 8 | 24/63 | 12.0 sec/it | loss 4.5246
# [11-14 21:21:22][flashy.solver][INFO] - Train | Epoch 8 | 36/63 | 11.8 sec/it | loss 4.5818
# [11-14 21:23:39][flashy.solver][INFO] - Train | Epoch 8 | 48/63 | 11.7 sec/it | loss 4.5749
# [11-14 21:25:57][flashy.solver][INFO] - Train | Epoch 8 | 60/63 | 11.7 sec/it | loss 4.5368
# [11-14 21:26:03][flashy.solver][INFO] - Train Summary | Epoch 8 | loss=4.5072 | duration=718.0236
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/site-packages/hydra/_internal/utils.py", line 220, in run_and_report
#     return func()
#            ^^^^^^
#   File "/usr/local/lib/python3.11/site-packages/hydra/_internal/utils.py", line 458, in <lambda>
#     lambda: hydra.run(
#             ^^^^^^^^^^
#   File "/usr/local/lib/python3.11/site-packages/hydra/_internal/hydra.py", line 119, in run
#     ret = run_job(
#           ^^^^^^^^
#   File "/usr/local/lib/python3.11/site-packages/hydra/core/utils.py", line 202, in run_job
#     os.chdir(old_cwd)
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick'

# %% [markdown]
# ### Evaluations

# %% [markdown]
# Key code:
# * `!dora grid nmi.main_table --dry_run --init` - shows a full list of all possible experiments per each study; each experiment has its own signature; we pass it when we want to start the experiment.
# * `!dora grid nmi.main_table '!seed' '!features' '!wer_random' --dry_run --init'` - shows a signature for each study.
# * `!dora run -f 6e3bf7d7 -d` - command to run a specific experiment.

# %%
# !dora grid nmi.main_table --dry_run --init
# Out:
# Hostname 2e465021a4a5 not defined in /conf/study_paths/study_paths.yaml. Using default paths.
# a
# Monitoring Grid nmi.main_table
# Base name:  model=clip_conv
#                                                                      Meta                                                                     | trai | vali |    test
# in  name                                                                                                                   sta       sig  sid | e  l | l  b | wer  wer_
#  0  dse.force_uid_assignement dse.selections=['audio_mous']                                                                N/A  34219380      | 0    |      |
#  1  dse.force_uid_assignement dse.selections=['audio_mous'] opt.epochs=1 opt.max_batches=1 tes.wer_random                  N/A  bcd967bc      | 0    |      |
#  2  dse.features=['MelSpectrum'] dse.force_uid_assignement dse.selections=['audio_mous']                                   N/A  029557fd      | 0    |      |
#  3  feature_model=deep_mel dse.features=['MelSpectrum'] dse.force_uid_assignement dse.selections=['audio_mous']            N/A  53f86c17      | 0    |      |
#  4  dse.features=['MelSpectrum'] dse.force_uid_assignement dse.selections=['audio_mous'] opt.loss=mse                      N/A  ca882d84      | 0    |      |
#  5  dse.selections=['gwilliams2022']                                                                                       N/A  52345878      | 0    |      |
#  6  dse.selections=['gwilliams2022'] opt.epochs=1 opt.max_batches=1 tes.wer_random                                         N/A  49e59834      | 0    |      |
#  7  dse.features=['MelSpectrum'] dse.selections=['gwilliams2022']                                                          N/A  43a218b2      | 0    |      |
#  8  feature_model=deep_mel dse.features=['MelSpectrum'] dse.selections=['gwilliams2022']                                   N/A  9ed4d4f3      | 0    |      |
#  9  dse.features=['MelSpectrum'] dse.selections=['gwilliams2022'] opt.loss=mse                                             N/A  ccb4b353      | 0    |      |
# 10  dse.selections=['broderick2019'] tes.wer_recordings=100                                                                N/A  557f5f8a      | 0    |      |
# 11  dse.selections=['broderick2019'] opt.epochs=1 opt.max_batches=1 tes.wer_random tes.wer_recordings=100                  N/A  ff8f3a2f      | 0    |      |
# 12  dse.features=['MelSpectrum'] dse.selections=['broderick2019'] tes.wer_recordings=100                                   N/A  a7e4621f      | 0    |      |
# 13  feature_model=deep_mel dse.features=['MelSpectrum'] dse.selections=['broderick2019'] tes.wer_recordings=100            N/A  8207605c      | 0    |      |
# 14  dse.features=['MelSpectrum'] dse.selections=['broderick2019'] opt.loss=mse tes.wer_recordings=100                      N/A  68c1a1e5      | 0    |      |
# 15                                                                                                                         N/A  6e3bf7d7      | 0    |      |
# 16  opt.epochs=1 opt.max_batches=1 tes.wer_random                                                                          N/A  c5455d58      | 0    |      |
# 17  dse.features=['MelSpectrum']                                                                                           N/A  87a001d2      | 0    |      |
# 18  feature_model=deep_mel dse.features=['MelSpectrum']                                                                    N/A  13767159      | 0    |      |
# 19  dse.features=['MelSpectrum'] opt.loss=mse                                                                              N/A  c512a1a6      | 0    |      |
# 20  dse.force_uid_assignement dse.selections=['audio_mous'] seed=2037                                                      N/A  59c3fedd      | 0    |      |
# 21  dse.force_uid_assignement dse.selections=['audio_mous'] opt.epochs=1 opt.max_batches=1 seed=2037 tes.wer_random        N/A  528367b9      | 0    |      |
# 22  dse.features=['MelSpectrum'] dse.force_uid_assignement dse.selections=['audio_mous'] seed=2037                         N/A  bce54762      | 0    |      |
# 23  feature_model=deep_mel dse.features=['MelSpectrum'] dse.force_uid_assignement dse.selections=['audio_mous'] seed=2037  N/A  10815196      | 0    |      |
# 24  dse.features=['MelSpectrum'] dse.force_uid_assignement dse.selections=['audio_mous'] opt.loss=mse seed=2037            N/A  14e245d9      | 0    |      |
# 25  dse.selections=['gwilliams2022'] seed=2037                                                                             N/A  5946f7ad      | 0    |      |
# 26  dse.selections=['gwilliams2022'] opt.epochs=1 opt.max_batches=1 seed=2037 tes.wer_random                               N/A  e8d15d1b      | 0    |      |
# 27  dse.features=['MelSpectrum'] dse.selections=['gwilliams2022'] seed=2037                                                N/A  9d111d4e      | 0    |      |
# 28  feature_model=deep_mel dse.features=['MelSpectrum'] dse.selections=['gwilliams2022'] seed=2037                         N/A  5b8b0655      | 0    |      |
# 29  dse.features=['MelSpectrum'] dse.selections=['gwilliams2022'] opt.loss=mse seed=2037                                   N/A  0b890699      | 0    |      |
# 30  dse.selections=['broderick2019'] seed=2037 tes.wer_recordings=100                                                      N/A  adc8346b      | 0    |      |
# 31  dse.selections=['broderick2019'] opt.epochs=1 opt.max_batches=1 seed=2037 tes.wer_random tes.wer_recordings=100        N/A  69712ead      | 0    |      |
# 32  dse.features=['MelSpectrum'] dse.selections=['broderick2019'] seed=2037 tes.wer_recordings=100                         N/A  896a10b2      | 0    |      |
# 33  feature_model=deep_mel dse.features=['MelSpectrum'] dse.selections=['broderick2019'] seed=2037 tes.wer_recordings=100  N/A  426029bd      | 0    |      |
# 34  dse.features=['MelSpectrum'] dse.selections=['broderick2019'] opt.loss=mse seed=2037 tes.wer_recordings=100            N/A  0edfcb98      | 0    |      |
# 35  seed=2037                                                                                                              N/A  884343d2      | 0    |      |
# 36  opt.epochs=1 opt.max_batches=1 seed=2037 tes.wer_random                                                                N/A  750d6954      | 0    |      |
# 37  dse.features=['MelSpectrum'] seed=2037                                                                                 N/A  ca0c1506      | 0    |      |
# 38  feature_model=deep_mel dse.features=['MelSpectrum'] seed=2037                                                          N/A  e1a95c9d      | 0    |      |
# 39  dse.features=['MelSpectrum'] opt.loss=mse seed=2037                                                                    N/A  f1cdb4e1      | 0    |      |
# 40  dse.force_uid_assignement dse.selections=['audio_mous'] seed=2038                                                      N/A  b220992a      | 0    |      |
# 41  dse.force_uid_assignement dse.selections=['audio_mous'] opt.epochs=1 opt.max_batches=1 seed=2038 tes.wer_random        N/A  f6a650ba      | 0    |      |
# 42  dse.features=['MelSpectrum'] dse.force_uid_assignement dse.selections=['audio_mous'] seed=2038                         N/A  48b35a15      | 0    |      |
# 43  feature_model=deep_mel dse.features=['MelSpectrum'] dse.force_uid_assignement dse.selections=['audio_mous'] seed=2038  N/A  365153df      | 0    |      |
# 44  dse.features=['MelSpectrum'] dse.force_uid_assignement dse.selections=['audio_mous'] opt.loss=mse seed=2038            N/A  c8968f15      | 0    |      |
# 45  dse.selections=['gwilliams2022'] seed=2038                                                                             N/A  bab9762f      | 0    |      |
# 46  dse.selections=['gwilliams2022'] opt.epochs=1 opt.max_batches=1 seed=2038 tes.wer_random                               N/A  988ff046      | 0    |      |
# 47  dse.features=['MelSpectrum'] dse.selections=['gwilliams2022'] seed=2038                                                N/A  3cc0489f      | 0    |      |
# 48  feature_model=deep_mel dse.features=['MelSpectrum'] dse.selections=['gwilliams2022'] seed=2038                         N/A  152b34e5      | 0    |      |
# 49  dse.features=['MelSpectrum'] dse.selections=['gwilliams2022'] opt.loss=mse seed=2038                                   N/A  ff4eb20a      | 0    |      |
# 50  dse.selections=['broderick2019'] seed=2038 tes.wer_recordings=100                                                      N/A  a7028f25      | 0    |      |
# 51  dse.selections=['broderick2019'] opt.epochs=1 opt.max_batches=1 seed=2038 tes.wer_random tes.wer_recordings=100        N/A  813077f4      | 0    |      |
# 52  dse.features=['MelSpectrum'] dse.selections=['broderick2019'] seed=2038 tes.wer_recordings=100                         N/A  3d97b459      | 0    |      |
# 53  feature_model=deep_mel dse.features=['MelSpectrum'] dse.selections=['broderick2019'] seed=2038 tes.wer_recordings=100  N/A  5b8e222b      | 0    |      |
# 54  dse.features=['MelSpectrum'] dse.selections=['broderick2019'] opt.loss=mse seed=2038 tes.wer_recordings=100            N/A  868b0132      | 0    |      |
# 55  seed=2038                                                                                                              N/A  d977efac      | 0    |      |
# 56  opt.epochs=1 opt.max_batches=1 seed=2038 tes.wer_random                                                                N/A  49b468a5      | 0    |      |
# 57  dse.features=['MelSpectrum'] seed=2038                                                                                 N/A  71007c6f      | 0    |      |
# 58  feature_model=deep_mel dse.features=['MelSpectrum'] seed=2038                                                          N/A  2c768010      | 0    |      |
# 59  dse.features=['MelSpectrum'] opt.loss=mse seed=2038                                                                    N/A  6bc9ab43      | 0    |      |

# %%
# !dora grid nmi.main_table '!seed' '!features' '!wer_random' --dry_run --init
# Out:
# Hostname 2e465021a4a5 not defined in /conf/study_paths/study_paths.yaml. Using default paths.
# a
# Monitoring Grid nmi.main_table
# Base name:  model=clip_conv
#                                      Meta                                      | trai | vali |    test
# i  name                                                     sta       sig  sid | e  l | l  b | wer  wer_
# 0  dse.force_uid_assignement dse.selections=['audio_mous']  N/A  34219380      | 0    |      |
# 1  dse.selections=['gwilliams2022']                         N/A  52345878      | 0    |      |
# 2  dse.selections=['broderick2019'] tes.wer_recordings=100  N/A  557f5f8a      | 0    |      |
# 3                                                           N/A  6e3bf7d7      | 0    |      |

# %%
# !dora run -f 6e3bf7d7
# Out:
# Hostname 2e465021a4a5 not defined in /conf/study_paths/study_paths.yaml. Using default paths.
# a
# Parser Injecting argv ['model=clip_conv', 'dset.selections=["brennan2019"]', 'seed=2036'] from sig 6e3bf7d7
# /usr/local/lib/python3.11/site-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
# See https://hydra.cc/docs/1.2/upgrades/1.1_to_1.2/changes_to_job_working_dir/ for more information.
#   ret = run_job(
# [2023-11-14 09:21:46,695][bm._env][WARNING] - Hostname 2e465021a4a5 not defined in /conf/study_paths/study_paths.yaml. Using default paths.
# [2023-11-14 09:21:47,196][bm.train][INFO] - For logs, checkpoints and samples, check /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/outputs/xps/6e3bf7d7.
# [2023-11-14 09:21:47,197][bm.train][INFO] - Caching intermediate data under /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/cache.
# [11-14 09:21:47][dora.distrib][INFO] - world_size is 1, skipping init.
# [11-14 09:21:47][bm.dataset][WARNING] - Requested 1000 recordings but only found 33
# [11-14 09:21:50][bm.dataset][INFO] - Loading Subjects | 6/33 | 9.14 it/sec
# [11-14 09:21:50][bm.dataset][INFO] - Loading Subjects | 12/33 | 10.14 it/sec
# [11-14 09:21:51][bm.dataset][INFO] - Loading Subjects | 18/33 | 10.60 it/sec
# [11-14 09:21:51][bm.dataset][INFO] - Loading Subjects | 24/33 | 9.83 it/sec
# [11-14 09:21:52][bm.dataset][INFO] - Loading Subjects | 30/33 | 10.19 it/sec
# [11-14 09:21:52][bm.dataset][INFO] - # Examples (train | valid | test): 26283 | 6154 | 6265
# [11-14 09:21:52][bm.train][INFO] - Model hash: b938bfafa07f08bc13f1d5792e81297f7bc271ea
# /usr/local/lib/python3.11/site-packages/flashy/loggers/tensorboard.py:47: UserWarning: tensorboard package was not found: use pip install tensorboard
#   warnings.warn("tensorboard package was not found: use pip install tensorboard")
# [11-14 09:21:53][bm.solver][INFO] - Fitting scaler. Dataset size=26283 samples.
# [11-14 09:23:37][bm.norm][INFO] - Fitting scalers | 6/33 | 14.9 sec/it
# [11-14 09:25:27][bm.norm][INFO] - Fitting scalers | 12/33 | 16.4 sec/it
# [11-14 09:27:26][bm.norm][INFO] - Fitting scalers | 18/33 | 17.6 sec/it
# [11-14 09:29:10][bm.norm][INFO] - Fitting scalers | 24/33 | 17.5 sec/it
# [11-14 09:30:49][bm.norm][INFO] - Fitting scalers | 30/33 | 17.3 sec/it
# [11-14 09:32:30][bm.norm][INFO] - features collected for norm: torch.Size([2957312, 1024])
# Process Process-67:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/multiprocessing/process.py", line 317, in _bootstrap
#     util._exit_function()
#   File "/usr/local/lib/python3.11/multiprocessing/util.py", line 360, in _exit_function
#     _run_finalizers()
#   File "/usr/local/lib/python3.11/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
#   File "/usr/local/lib/python3.11/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/multiprocessing/queues.py", line 199, in _finalize_join
#     thread.join()
#   File "/usr/local/lib/python3.11/threading.py", line 1112, in join
#     self._wait_for_tstate_lock()
#   File "/usr/local/lib/python3.11/threading.py", line 1132, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# ^C

# %%
# !dora run -f 6e3bf7d7 -d
# Out:
# Hostname d236674f7fcb not defined in /conf/study_paths/study_paths.yaml. Using default paths.
# a
# Parser Injecting argv ['model=clip_conv', 'dset.selections=["gwilliams2022"]', 'seed=2036'] from sig 6e3bf7d7
# Executor: Starting 1 worker processes for DDP.
# Hostname d236674f7fcb not defined in /conf/study_paths/study_paths.yaml. Using default paths.
# a
# /usr/local/lib/python3.11/site-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
# See https://hydra.cc/docs/1.2/upgrades/1.1_to_1.2/changes_to_job_working_dir/ for more information.
#   ret = run_job(
# [2023-11-11 22:00:56,660][bm._env][WARNING] - Hostname d236674f7fcb not defined in /conf/study_paths/study_paths.yaml. Using default paths.
# [2023-11-11 22:00:56,662][bm.train][INFO] - For logs, checkpoints and samples, check /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/outputs/xps/6e3bf7d7.
# [2023-11-11 22:00:56,662][bm.train][INFO] - Caching intermediate data under /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/cache.
# [11-11 22:00:56][dora.distrib][INFO] - world_size is 1, skipping init.
# [11-11 22:00:57][bm.dataset][WARNING] - Requested 1000 recordings but only found 196
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# Executor: Received keyboard interrupt, trying to kill all workers.
# /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/bm/studies/gwilliams2022.py:105: RuntimeWarning: The unit for channel(s) MISC 001, MISC 002, MISC 003, MISC 004, MISC 005, MISC 006, MISC 007, MISC 008, MISC 009, MISC 010, MISC 011, MISC 012, MISC 013, MISC 014, MISC 015, MISC 016, MISC 017, MISC 018, MISC 019, MISC 020, MISC 021, MISC 022, MISC 023, MISC 024, MISC 025, MISC 026, MISC 027, MISC 028, MISC 029, MISC 030, MISC 031, MISC 032 has changed from V to NA.
#   raw = read_raw_bids(bids_path)  # FIXME this is NOT a lazy read
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-f0860e701046> in <cell line: 1>()
# ----> 1 get_ipython().system('dora run -f 6e3bf7d7 -d')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#      97       kwargs.update({'also_return_output': True})
#      98
# ---> 99     output = _system_commands._system_compat(self, *args, **kwargs)  # pylint:disable=protected-access
#     100
#     101     if pip_warn:
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_system_commands.py in _system_compat(shell, cmd, also_return_output)
#     452   # is expected to call this function, thus adding one level of nesting to the
#     453   # stack.
# --> 454   result = _run_command(
#     455       shell.var_expand(cmd, depth=2), clear_streamed_output=False
#     456   )
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_system_commands.py in _run_command(cmd, clear_streamed_output)
#     202       os.close(child_pty)
#     203
# --> 204       return _monitor_process(parent_pty, epoll, p, cmd, update_stdin_widget)
#     205   finally:
#     206     epoll.close()
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_system_commands.py in _monitor_process(parent_pty, epoll, p, cmd, update_stdin_widget)
#     232   while True:
#     233     try:
# --> 234       result = _poll_process(parent_pty, epoll, p, cmd, decoder, state)
#     235       if result is not None:
#     236         return result
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_system_commands.py in _poll_process(parent_pty, epoll, p, cmd, decoder, state)
#     280   output_available = False
#     281
# --> 282   events = epoll.poll()
#     283   input_events = []
#     284   for _, event in events:
#
# KeyboardInterrupt:

# %%
# !python -m scripts.run_eval_probs grid_name="main_table"
# Out:
# Hostname d236674f7fcb not defined in /conf/study_paths/study_paths.yaml. Using default paths.
# a
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/scripts/run_eval_probs.py", line 471, in <module>
#     assert grid_dir.exists(), f"{grid_dir} does not exists"
# AssertionError: /content/drive/MyDrive/11785 _DL/Final_project/Baseline_model/brainmagick/outputs/grids/main_table does not exists

# %% [markdown]
# ### Tests

# %%
#!pytest bm

# %% [markdown]
# ### Visualization of metrics

# %%
#!pip install hiplot

# %%
#!python -m hiplot dora.hiplot.load --port=5005
