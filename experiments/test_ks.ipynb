# %% [markdown]
# ## Replicating Meta AI model from scratch

# %% [markdown]
# Meta AI: https://github.com/facebookresearch/brainmagick/tree/main

# %% [markdown]
# ## Installs and imports

# %%
# !pip install wandb torchsummaryX mne transformers -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 9.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 16.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 12.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 249.2/249.2 kB 13.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 3.8 MB/s eta 0:00:00

# %%
### Torch
import  torch
import  torch.nn as nn
import  torch.nn.functional as F
from    torch.optim import lr_scheduler
from    torchsummaryX import summary
from    torch.utils.data import Dataset, DataLoader
import  torchaudio
import  torchaudio.transforms as tat

### General
import  random
import  numpy as np
import  pandas as pd
import  scipy
import  gc
from    tqdm.auto import tqdm
import  os
import  datetime
import  time
import  wandb
import  matplotlib.pyplot as plt
import  seaborn as sns

# wav2vec2 and EEG processing
from    transformers import (AutoProcessor, AutoModelForPreTraining,
                             CLIPProcessor, CLIPModel)
import  mne

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Config

# %%
cd /content/drive/MyDrive/11785_DL/Final_project/2_Baseline_model/brainmagick/data/brennan2019/download
# Out:
# /content/drive/MyDrive/11785_DL/Final_project/2_Baseline_model/brainmagick/data/brennan2019/download

# %%
BRAIN_PATH = '/content/drive/MyDrive/11785_DL/Final_project/2_Baseline_model/brainmagick/data/brennan2019/download'
AUDIO_PATH = '/content/drive/MyDrive/11785_DL/Final_project/2_Baseline_model/brainmagick/data/brennan2019/download/audio'
PROC_PATH = '/content/drive/MyDrive/11785_DL/Final_project/2_Baseline_model/brainmagick/data/brennan2019/download/proc'

# %% [markdown]
# ## Datasets and EDA

# %%
#

# %% [markdown]
# ## Dataloaders

# %%
#

# %% [markdown]
# ## Model

# %%
#

# %% [markdown]
# ## Loss, optimizers, scheduler

# %%
#

# %% [markdown]
# ## Train and validation functions

# %%
#

# %% [markdown]
# ## WandB

# %%
#

# %% [markdown]
# ## Training/experiments

# %%
#

# %% [markdown]
# ## Testing

# %%
#
